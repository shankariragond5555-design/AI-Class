# %%
print("Hello World")
# Out:
# Hello World

# %%
a=10

# %%
print(a)
# Out:
# 10

# %%
print(id(a))
# Out:
# 140715088512200

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
b=20

# %%
print(b)
# Out:
# 20

# %%
print(id(b))
# Out:
# 140715088512520

# %%
print(type(b))
# Out:
# <class 'int'>
