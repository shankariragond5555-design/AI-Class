# %% [markdown]
# string

# %%
name="shankar"

# %%
print(name)
# Out:
# shankar

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
age=25.5

# %%
print(type(age))
# Out:
# <class 'float'>

# %%
name1='shankar'

# %%
print(name1)
# Out:
# shankar

# %%
print(type(name1))
# Out:
# <class 'str'>

# %%
name2='''shankar'''

# %%
print(name2)
# Out:
# shankar

# %%
print(type(name2))
# Out:
# <class 'str'>

# %%
name3="""shivanya"""

# %%
print(name3)
# Out:
# shivanya

# %%
print(type(name3))
# Out:
# <class 'str'>

# %%
age=25

# %%
age=int(age)

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
print(age)
# Out:
# 25

# %%
a="10"
b="20"

# %%
c=a+b

# %%
print(c)
# Out:
# 1020

# %%
print(type(c))
# Out:
# <class 'str'>

# %%
a1=int(a)

# %%
print(a1)
# Out:
# 10

# %%
print(type(a1))
# Out:
# <class 'int'>

# %%
b1=int(b)

# %%
print(type(b1))
# Out:
# <class 'int'>

# %%
c1=a1+b1

# %%
print(c1)
# Out:
# 30

# %%
print(type(c1))
# Out:
# <class 'int'>

# %% [markdown]
# Multi-line string

# %%
intro='''
My name is shankar
I am from india
I have completed my Engg. in comp science'''

# %%
print(intro)
# Out:
# My name is shankar
# I am from india
# I have completed my Engg. in comp science

# %% [markdown]
# Multi line using single inv. comma

# %%
intro='my name is shankar\
    I am from India\
I have completed my Engg in comp science'

# %%
print(intro)
# Out:
# my name is shankar    I am from IndiaI have completed my Engg in comp science

# %%
#intro='my name is shankar

# %% [markdown]
# Handling Escape character

# %%
str6="let's play cricket"

# %%
print(str6)
# Out:
# let's play cricket

# %% [markdown]
# Indexing - poitive indexing- which starts from 0 and start

# %%
str9="welcome to india"

# %%
print(str9)
# Out:
# welcome to india

# %%
print(str9[13])
# Out:
# d

# %%
print(str9[4])
# Out:
# o

# %%
print(str9[11])
# Out:
# i

# %%
print(str9[1])
# Out:
# e

# %% [markdown]
# Indexing - negative indexing - which starts from -1 and last

# %%
str10="welcome to india"

# %%
print(str10)
# Out:
# welcome to india

# %%
print(str10[-3])
# Out:
# d

# %%
print(str10[-12])
# Out:
# o

# %%
print(str10[-5])
# Out:
# i

# %%
print(str10[-15])
# Out:
# e

# %% [markdown]
# Slicing - Extract/ accessing substring

# %%
str11="welcome to india"

# %%
print(str11)
# Out:
# welcome to india

# %%
print(str11[11:16])
# Out:
# india

# %%
print(str11[0:7])
# Out:
# welcome

# %%
print(str11[8:16])
# Out:
# to india

# %%
print(str11[13:16])
# Out:
# dia

# %%
print(str11[:7])

# %%
print(str11[:])
# Out:
# welcome to india

# %%
print(str11[11:])
# Out:
# india

# %%
print(str11[0:7:1])
# Out:
# welcome

# %%
print(str11[0:16])
# Out:
# welcome to india

# %%
print(str11[0:7:2])
# Out:
# wloe

# %%
print(str11[0:7:3])
# Out:
# wce

# %%
print(str11[::])
# Out:
# welcome to india

# %%
print(str11[0:16:1])
# Out:
# welcome to india
