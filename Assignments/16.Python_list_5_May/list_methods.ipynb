# %% [markdown]
# ## List Methods

# %% [markdown]
# # Adding Elements

# %% [markdown]
#  #### 1. append()

# %%
list1=[10,20,30]

# %%
print(list1)
# Out:
# [10, 20, 30]

# %%
print(id(list1))
# Out:
# 4435841792

# %%
list1.append(40)

# %%
print(list1)
# Out:
# [10, 20, 30, 40]

# %%
print(id(list1))
# Out:
# 4435600448

# %% [markdown]
#  #### 2. insert()

# %%
list1=[10,20,30,40,50]

# %%
list1.insert(4,45)

# %%
print(list1)
# Out:
# [10, 20, 30, 40, 45, 50]

# %%
list1.insert(0,5)

# %%
print(list1)
# Out:
# [5, 10, 20, 30, 40, 45, 50]

# %%
list1.insert(7,60)

# %%
print(list1)
# Out:
# [5, 10, 20, 30, 40, 45, 50, 60]

# %%
list1.insert(10,60)

# %%
list1
# Out:
# [5, 10, 20, 30, 40, 45, 50, 60, 60]

# %%
print(list1[7])
# Out:
# 60

# %%
print(list1[8])
# Out:
# 60

# %%
print(list1[9])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 print(list1[9])
#
# IndexError: list index out of range

# %%
list1
# Out:
# [5, 10, 20, 30, 40, 45, 50, 60, 60]

# %%
list1.append("akshay")

# %%
list1
# Out:
# [5, 10, 20, 30, 40, 45, 50, 60, 60, 'akshay']

# %%
list1.insert(8,65.5)

# %%
list1
# Out:
# [5, 10, 20, 30, 40, 45, 50, 60, 65.5, 60, 'akshay']

# %% [markdown]
#  #### 3. extend()

# %%
list1=[10,20,30]

# %%
list2=[50,60,70,80]

# %%
list1.extend(list2)

# %%
list1
# Out:
# [10, 20, 30, 50, 60, 70, 80]

# %% [markdown]
# # removing Elements

# %% [markdown]
# #### 1.remove()

# %%
list1=[10,20,30,40,50,30]

# %%
list1.remove(30)

# %%
print(list1)
# Out:
# [10, 20, 40, 50, 30]

# %% [markdown]
# #### 2. pop()

# %%
list1=[10,20,30,40,50]

# %%
list1.pop()
# Out:
# 50

# %%
print(list1)
# Out:
# [10, 20, 30, 40]

# %% [markdown]
# #### 2. pop(index)

# %%
list1=[10,20,30,40,50]

# %%
list1.pop(2)
# Out:
# 30

# %%
print(list1)
# Out:
# [10, 20, 40, 50]

# %% [markdown]
# #### 3. clear()

# %%
list1=[10,20,30,40,50]

# %%
list1.clear()

# %%
print(list1)
# Out:
# []

# %% [markdown]
# # Searching and counting

# %% [markdown]
# #### 1. index()

# %%
list1=[10,20,30,40,50,10]

# %%
position=list1.index(10)

# %%
print(position)
# Out:
# 0

# %% [markdown]
# #### 2. count()

# %%
list1=[10,20,30,10,40,50,10]

# %%
occurance=list1.count(10)

# %%
print(occurance)
# Out:
# 3

# %% [markdown]
# # Sorting and reversing

# %% [markdown]
# #### 1.sort()

# %%
list1=[50,20,40,10,30]

# %%
list1.sort()

# %%
print(list1)
# Out:
# [10, 20, 30, 40, 50]

# %% [markdown]
# #### 2.reverse()

# %%
list1=[50,20,40,10,30]

# %%
list1.reverse()

# %%
print(list1)
# Out:
# [30, 10, 40, 20, 50]

# %% [markdown]
# #### 3.copy()

# %%
list1=[10,20,30,40,50]

# %%
list2=list1.copy()

# %%
print(list1)
# Out:
# [10, 20, 30, 40, 50]

# %%
print(list2)
# Out:
# [10, 20, 30, 40, 50]

# %%
print(id(list1))
# Out:
# 4436055424

# %%
print(id(list2))
# Out:
# 4436108416

# %% [markdown]
# # List Comparision

# %%
a=[1,2,3,4]

# %%
b=[1,2,5]

# %%
print(a<b)
# Out:
# True

# %%
print(a>b)
# Out:
# False

# %%
a=[1,2,3]
b=[1,2,3,4]

# %%
print(a<b)
# Out:
# True
