# %% [markdown]
# Strings Methods

# %% [markdown]
# Syntax:
#
# string_variable_name.method_name()
#
# str1.upper()

# %%
str1="Shankar"

# %%
print(str1.upper())
# Out:
# SHANKAR

# %%
print(str1.lower())
# Out:
# shankar

# %% [markdown]
# Content test Methods

# %% [markdown]
# 1. isalpha() : checks if all characters are alphabets

# %%
greetings="Helloworld"

# %%
print(greetings.isalpha())
# Out:
# True

# %%
greetings1="Hello world1"

# %%
print(greetings1.isalpha())
# Out:
# False

# %%
greetings2="hello world$"

# %%
print(greetings2.isalpha())
# Out:
# False

# %% [markdown]
# 2. isdigit() : checks if all characters are digits

# %%
str1="724959"

# %%
print(str1.isdigit())
# Out:
# True

# %%
str2="14070s"

# %%
print(str2.isdigit())
# Out:
# False

# %%
str3="80405$"

# %%
print(str3.isdigit())
# Out:
# False

# %% [markdown]
# 3.isalnum() : checks if all characters are alphabests or digits

# %%
str3="Hello1443"

# %%
print(str3.isalnum())
# Out:
# True

# %%
str4="hello415$"

# %%
print(str4.isalnum())
# Out:
# False

# %% [markdown]
# 4. islower() - Checks if all characters are lowercase

# %%
str5="hello"

# %%
print(str5.islower())
# Out:
# True

# %%
str6="Hello"

# %%
print(str6.islower())
# Out:
# False

# %% [markdown]
# 5. isupper() - Checks if all characters are uppercase

# %%
str6="HELLO"

# %%
print(str6.isupper())
# Out:
# True

# %%
str7="hELLO"

# %%
print(str7.isupper())
# Out:
# False

# %% [markdown]
# 6. startswith() - checks if string starts with value

# %%
str8="hello world"

# %%
print(str8.startswith("hello"))
# Out:
# True

# %%
str9="hi world"

# %%
print(str9.startswith("hello"))
# Out:
# False

# %% [markdown]
# 7. endswith() - checks if string ends with value

# %%
str10="hello world"

# %%
print(str10.endswith("world"))
# Out:
# True

# %%
str11="hello india"

# %%
print(str11.endswith("world"))
# Out:
# False

# %% [markdown]
# Search Methods

# %% [markdown]
# 1. find() : returns/print lowest index of substring/vaule/word that we provide as a parameter to the method
#
# and if substring not found, it returns -1

# %%
str12="Hello, welcome to python programming"

# %%
print(str12.find("python"))
# Out:
# 18

# %%
print(str12.find("Python"))
# Out:
# -1

# %%
print(str12.find("java"))
# Out:
# -1
