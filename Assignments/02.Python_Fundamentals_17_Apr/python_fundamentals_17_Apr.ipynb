# %%
age=25

# %%
print(age)
# Out:
# 25

# %%
print(Age)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(Age)
#
# NameError: name 'Age' is not defined

# %%
A=10

# %%
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(a)
#
# NameError: name 'a' is not defined

# %%
print(A)
# Out:
# 10

# %%
def sum(a,b):
    return a+b

result=sum(10,20)

# %%
print(result)
# Out:
# 30

# %% [markdown]
# ## Python is case sensitive language

# %%
A=10
a=20

# %%
print(A)
# Out:
# 10

# %%
print(a)
# Out:
# 20

# %% [markdown]
# ## Rules for Creating Identifiers

# %%
Age=10

# %%
z123=25

# %%
_z_=10

# %%
def=25
# Out:
#   Cell In[21], line 1
#     def=25
#        ^
# SyntaxError: invalid syntax

# %%
a=25

# %%
age=25

# %%
name="rajesh"

# %%
salary=10000.15

# %% [markdown]
# ## Basic Data Types in Python

# %% [markdown]
# ## Integer

# %%
age=25

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
weight=65.6

# %%
print(type(weight))
# Out:
# <class 'float'>

# %%
num=1+2j

# %%
print(type(num))
# Out:
# <class 'complex'>

# %%
Voting=False

# %%
print(type(Voting))
# Out:
# <class 'bool'>

# %%
name='rajesh'

# %%
print(type(name))
# Out:
# <class 'str'>

# %% [markdown]
# ## Float- decimal

# %%
pi=3.14

# %%
print(type(pi))
# Out:
# <class 'float'>

# %%
pi_exp=3.14e2

# %%
print(pi_exp)
# Out:
# 314.0

# %%
print(type(pi_exp))
# Out:
# <class 'float'>

# %% [markdown]
# ## Complex data type

# %%
c1=1+2j

# %%
print(type(c1))
# Out:
# <class 'complex'>

# %% [markdown]
# ## Bool data type

# %%
is_active=True

# %%
print(type(is_active))
# Out:
# <class 'bool'>

# %%
is_deleted=False

# %%
print(type(is_deleted))
# Out:
# <class 'bool'>

# %% [markdown]
# ## String data type

# %%
name= 'rajeshRAJESH!@#$%^&*()+_?1238996+-'

# %%
print(name)
# Out:
# rajeshRAJESH!@#$%^&*()+_?1238996+-

# %%
college= "JSPM"

# %%
address= '''PCMC'''

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
print(type(college))
# Out:
# <class 'str'>

# %%
print(type(address))
# Out:
# <class 'str'>

# %% [markdown]
# ## Variable Assignment

# %%
age=10
weight=65.6
num=1+2j
eligible_for_voting=True
name="rajesh"

# %%
print(age,weight,num,eligible_for_voting,name)
# Out:
# 10 65.6 (1+2j) True rajesh

# %%
age,weight,num,eligible_for_voting,name=20,75.6,1+2j,False,"Ramesh"

# %%
print(age,weight,num,eligible_for_voting,name)
# Out:
# 20 75.6 (1+2j) False Ramesh
