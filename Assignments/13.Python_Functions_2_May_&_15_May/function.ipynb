# %%
print("program started")

def summation():
    num1=10
    num2=20
    result=num1+num2
    print(result)

summation()
summation()
summation()
print("program execution completed")
# Out:
# program started
# 30
# 30
# 30
# program execution completed

# %%
print("program started")

def cal_sum_mul(x,y,z):
    sum=x+y+z
    mul=x*y*z
    #print(result)
    return sum,mul

final_sum,final_mul=cal_sum_mul(10,20,30)
print(final_sum)
print(final_mul)
print("program ends")
# Out:
# program started
# 60
# 6000
# program ends

# %%
print("start")

def greet(name,age):
    print("my name is",name)
    print("my age is",age)

greet(age=25,name="Akshay")
print("end")
# Out:
# start
# my name is Akshay
# my age is 25
# end
