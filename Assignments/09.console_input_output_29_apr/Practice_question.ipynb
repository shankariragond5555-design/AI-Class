# %%
# Q1. What will be the output of the following? Also predict whether it returns True or False.
# pythonlanguage = "Python"
# print(language.upper())
# print(language.lower())

# %%
pythonlanguage = "Python"
print(pythonlanguage.upper())
print(pythonlanguage.lower())
# Out:
# PYTHON
# python

# %%
# Q2. Check whether the string below contains only alphabets. Write the code and state why the result is True or False.
# pythoncourse = "DataScience"
# print(course.isalpha())

# %%
pythoncourse = "DataScience"
print(pythoncourse.isalpha())
# Out:
# True

# %%
# Q3. Predict the output of each print statement and explain the difference.
# pythonusername = "Admin99"
# print(username.isalpha())
# print(username.isdigit())
# print(username.isalnum())

# %%
pythonusername = "Admin99"
print(pythonusername.isalpha())
print(pythonusername.isdigit())
print(pythonusername.isalnum())
# Out:
# False
# False
# True

# %%
# Q4. What will be the output? Justify your answer for each line.
# pythonpin = "4872"
# print(pin.isdigit())
# pin2 = "48.72"
# print(pin2.isdigit())


pythonpin = "4872"
print(pythonpin.isdigit())
pin2 = "48.72"
print(pin2.isdigit())
# Out:
# True
# False

# %%
# Q5. Predict the output of both print statements and explain the behavior of islower().
# pythonword1 = "hello world"
# word2 = "Hello World"
# print(word1.islower())
# print(word2.islower())


pythonword1 = "hello world"
pythonword2 = "Hello World"
print(pythonword1.islower())
print(word2.islower())
# Out:
# True
# False

# %%
# Q6. What will be printed? State when isupper() returns True vs False.
# pythontag1 = "PYTHON"
# tag2 = "PyTHON"
# print(tag1.isupper())
# print(tag2.isupper())

pythontag1 = "PYTHON"
pythontag2 = "PyTHON"
print(pythontag1.isupper())
print(pythontag2.isupper())
# Out:
# True
# False

# %%
# Q7. What is the output of the following? Also explain what startswith() checks.
# pythonemail = "contact@gmail.com"
# print(email.startswith("contact"))
# print(email.startswith("gmail"))


pythonemail = "contact@gmail.com"
print(pythonemail.startswith("contact"))
print(pythonemail.startswith("gmail"))
# Out:
# True
# False

# %%
# Q8. Predict the output. Then explain why the second print gives False.
# pythonfilename = "report_2024.pdf"
# print(filename.endswith(".pdf"))
# print(filename.endswith(".docx"))


from fileinput import filename
pythonfilename = "report_2024.pdf"
print(pythonfilename.endswith(".pdf"))
print(pythonfilename.endswith(".docx"))
# Out:
# True
# False

# %%
# Q9. What will find() return in each case? Write the output and explain.
# pythonsentence = "Hello, welcome to python programming"
# print(sentence.find("python"))
# print(sentence.find("Python"))
# print(sentence.find("java"))


pythonsentence = "Hello, welcome to python programming"
print(pythonsentence.find("python"))
print(pythonsentence.find("Python"))
print(pythonsentence.find("java"))
# Out:
# 18
# -1
# -1

# %%
# Q10. Use len(), min(), and max() on the string below and write what each one returns.
# pythoncity = "Mumbai"
# print(len(city))
# print(min(city))
# print(max(city))

pythoncity = "Mumbai"
print(len(pythoncity))
print(min(pythoncity))
print(max(pythoncity))
# Out:
# 6
# M
# u

# %%
# Q11. Given the string below, use startswith() and endswith() together to check if it looks like a valid Python filename.
# pythonfname = "assignment1.py"
# print(fname.startswith("assignment"))
# print(fname.endswith(".py"))

pythonfname = "assignment1.py"
print(pythonfname.startswith("assignment"))
print(pythonfname.endswith(".py"))
# Out:
# True
# True

# %%
# Q12. Predict the output. What is the difference between isalpha() and isalnum()?
# pythonval1 = "Rupee100"
# val2 = "Rupee"
# print(val1.isalpha())
# print(val1.isalnum())
# print(val2.isalpha())
# print(val2.isalnum())

pythonval1 = "Rupee100"
val2 = "Rupee"      
print(pythonval1.isalpha())
print(pythonval1.isalnum())
print(val2.isalpha())
print(val2.isalnum())
# Out:
# False
# True
# True
# True

# %%
# Q13. What index does find() return for 'india' in the string below? Verify using indexing.
# pythonphrase = "welcome to india"
# idx = phrase.find("india")
# print(idx)
# print(phrase[idx:idx+5])

pythonphrase = "welcome to india"
idx = pythonphrase.find("india")        
print(idx)
print(pythonphrase[idx:idx+5])
# Out:
# 11
# india

# %%
# Q14. What will be the output? Explain the role of len() as a built-in function vs a method.
# pythonproduct = "Laptop"
# print(len(product))
# print(max(product))
# print(min(product))

pythonproduct = "Laptop"
print(len(pythonproduct))
print(max(pythonproduct))
print(min(pythonproduct))
# Out:
# 6
# t
# L

# %%
# Q15. Write code to check all of the following for the string below and predict each output.
# pythondata = "HelloWorld"
# print(data.isalpha())
# print(data.islower())
# print(data.isupper())
# print(data.startswith("Hello"))
# print(data.endswith("World"))

pythondata = "HelloWorld"
print(pythondata.isalpha())     
print(pythondata.islower())     
print(pythondata.isupper())     
print(pythondata.startswith("Hello"))     
print(pythondata.endswith("World"))
# Out:
# True
# False
# False
# True
# True
