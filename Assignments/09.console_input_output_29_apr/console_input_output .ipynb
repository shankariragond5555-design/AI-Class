# %% [markdown]
# ## Console input Output

# %% [markdown]
# ### input()

# %%
age=input()

# %%
print(age)
# Out:
# 25

# %%
age=input("Enter your age:")

# %%
print(age)
# Out:
# 28

# %%
print(type(age))      # "28"
# Out:
# <class 'str'>

# %%
name=input("Enter your first name:")

# %%
print(name)
# Out:
# Akshay

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
input_value=input("Enter any value:")
print(type(input_value))
# Out:
# <class 'str'>

# %% [markdown]
# ### accepting two values and return its addition - Problem

# %%
num1=input("Enter first value:") #10

# %%
print(num1)
# Out:
# 10

# %%
num2=input("Enter second value")  #20

# %%
print(num2)
# Out:
# 20

# %%
result=num1+num2  #30

# %%
print(result)
# Out:
# 1020

# %%
# "10"+"20" = "1020"

# %% [markdown]
# ### int() - built in function

# %%
num1=input("Enter first value:") #10

# %%
print(num1)  # "10" -> 10 , "10.1" -> 10.1
# Out:
# 10

# %%
print(type(num1))
# Out:
# <class 'str'>

# %%
num2=int(num1)

# %%
print(num2)
# Out:
# 10

# %%
print(type(num2))
# Out:
# <class 'int'>

# %% [markdown]
# ### accepting two values and return its addition - Solution1

# %%
num1=input("Enter first value:") #10

# %%
print(num1)
# Out:
# 10

# %%
print(id(num1))
# Out:
# 4485977728

# %%
print(type(num1))
# Out:
# <class 'str'>

# %%
num1=int(num1) # "10"->10

# %%
print(type(num1))
# Out:
# <class 'int'>

# %%
num2=input("Enter second value")  #20

# %%
print(num2)
# Out:
# 20

# %%
print(id(num2))
# Out:
# 4486613680

# %%
print(type(num2))
# Out:
# <class 'str'>

# %%
num2=int(num2)

# %%
print(type(num2))
# Out:
# <class 'int'>

# %%
print(num2)
# Out:
# 20

# %%
result=num1+num2  #30

# %%
print(result)
# Out:
# 30

# %%
print(id(result))
# Out:
# 4369888128

# %% [markdown]
# ### accepting two values and return its addition - Solution2 - convert on same line

# %%
#num1=input("Enter first value:") #10

# %%
num1=int(input("Enter first value:")) # "20"->20 -> num1

# %%
#num2=input("Enter second value")  #20

# %%
num2=int(input("Enter second value"))

# %%
result=num1+num2  #30

# %%
print(result)
# Out:
# 50

# %% [markdown]
# ### memory address and value printing

# %%
num1=10

# %%
print(num1)
# Out:
# 10

# %%
print(id(num1))
# Out:
# 4369887488

# %%
num1=10.1

# %%
print(num1)
# Out:
# 10.1

# %%
print(id(num1))
# Out:
# 4479960464

# %%
print(num1)
# Out:
# 10.1

# %%
list1=[10,20,30]

# %%
print(list1)
# Out:
# [10, 20, 30]

# %%
print(id(list1))
# Out:
# 4486716672

# %%
list1[0]=15

# %%
print(list1)
# Out:
# [15, 20, 30]

# %%
print(id(list1))
# Out:
# 4486716672
