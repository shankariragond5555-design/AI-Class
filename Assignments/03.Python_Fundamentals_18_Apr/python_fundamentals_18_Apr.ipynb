# %% [markdown]
# ## Arthmatic Opertors
#
# 1.Addition (+)

# %%
a=10
print(a)
print(id(a))
# Out:
# 10
# 140715088512200

# %%
b=15
print(b)
print(id(b))
# Out:
# 15
# 140715088512360

# %%
c=a+b  #10+15
print(c)
print(id(c))
# Out:
# 25
# 140715088512680

# %% [markdown]
# Substraction

# %%
p=20
q=5
r=p-q

# %%
print(r)
# Out:
# 15

# %% [markdown]
# Multiplication

# %%
x=15
y=3
z=x*y
print(z)
# Out:
# 45

# %% [markdown]
# Division

# %%
a=55
b=11
c=a/b
print(c)
# Out:
# 5.0

# %% [markdown]
# Floor Division

# %%
a=90
b=18
c=a//b
print(c)
# Out:
# 5

# %% [markdown]
# Modulus (%)

# %%
a=25
b=5
c=a%b
print(c)
# Out:
# 0

# %% [markdown]
# Exponential (**) ->Raise to power

# %%
#4^2->2*2
#4^3->4*4*4

# %%
a=4
b=5
c=a**b
print(c)
# Out:
# 1024

# %% [markdown]
# Comments in Python

# %%
#d=20
b=10 # 10 is stored in b 
c=a+b #c is addition of a and b
#print(d)

# %% [markdown]
# Precedence in Python

# %%
result=(10+5)*2

# %%
print(result)
# Out:
# 30

# %%
result=10+5**2

# %%
print(result)
# Out:
# 35

# %%
result=10-2+5

# %%
print(result)
# Out:
# 13

# %% [markdown]
# Type conversions

# %%
a=4.8
result=int(a)
print(result)
# Out:
# 4

# %%
print(type(a))
# Out:
# <class 'float'>

# %%
print(type(result))
# Out:
# <class 'int'>

# %% [markdown]
# string to integer

# %%
b="200"
print(type(b))
# Out:
# <class 'str'>

# %%
result=int(b)
print(result)
# Out:
# 200

# %%
print(type(result))
# Out:
# <class 'int'>

# %% [markdown]
# boolean to integer

# %%
a=False
print(type(a))
# Out:
# <class 'bool'>

# %%
result=int(a)

# %%
print(result)
# Out:
# 0

# %%
print(type(result))
# Out:
# <class 'int'>
