# %% [markdown]
# ## Console input Output

# %% [markdown]
# ### output- print()

# %%
print(10)
print(type(10))
# Out:
# 10
# <class 'int'>

# %%
print(10.1)
print(type(10.1))
# Out:
# 10.1
# <class 'float'>

# %%
print(1+2j)
print(type(1+2j))
# Out:
# (1+2j)
# <class 'complex'>

# %%
print("Rahul")
print(type("Rahul"))
# Out:
# Rahul
# <class 'str'>

# %%
print(True)
print(type(True))
# Out:
# True
# <class 'bool'>

# %%
name="Rajesh"

# %%
print(name)
# Out:
# Rajesh

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
print(id(name))
# Out:
# 4519997008

# %%
height=5.8

# %%
print(height)
# Out:
# 5.8

# %%
print(type(height))
# Out:
# <class 'float'>

# %%
weight=65.7

# %%
print(name, height,weight)
# Out:
# Rajesh 5.8 65.7

# %%
name="Akshay"

# %%
print(name)
# Out:
# Akshay

# %%
print("My name is :",name)
# Out:
# My name is : Akshay

# %%
print("my weight is -",weight)
# Out:
# my weight is - 65.7

# %%
print("my height is:",height,"my weight is:",weight)
# Out:
# my height is: 5.8 my weight is: 65.7

# %%
print(name, height,weight)
# Out:
# Akshay 5.8 65.7

# %%
print(name, height,weight,sep="-")
# Out:
# Akshay-5.8-65.7

# %%
print(name, height,weight)
# Out:
# Akshay 5.8 65.7

# %%
print(name,end=" ")
print(height,end=" ")
print(weight)
# Out:
# Rajesh 5.8 65.7

# %%
print(name,end="\n")
print(height,end="\n")
print(weight,end="\n")
print("program execuated")
# Out:
# Akshay
# 5.8
# 65.7
# program execuated

# %% [markdown]
# ### input - input()

# %%
age=input()

# %%
print(age)

# %%
age=input("Enter your age:")

# %%
print(age)
# Out:
# 28

# %%
print(type(age))      # "28"
# Out:
# <class 'str'>

# %%
name=input("Enter your first name:")

# %%
print(name)
# Out:
# Akshay

# %%
print(type(name))
# Out:
# <class 'str'>
