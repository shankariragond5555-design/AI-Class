# %%
# Q1. What will be the output of all five print statements? Also state the data type of each.
# print(10)
# print(type(10))
# print(10.1)
# print(type(10.1))
# print(1+2j)
# print(type(1+2j))
# print("Rahul")
# print(type("Rahul"))
# print(True)
# print(type(True))

print(10)
print(type(10))
print(10.1)
print(type(10.1))
print(1+2j)
print(type(1+2j))
print("Rahul")
print(type("Rahul"))
print(True)
print(type(True))
# Out:
# 10
# <class 'int'>
# 10.1
# <class 'float'>
# (1+2j)
# <class 'complex'>
# Rahul
# <class 'str'>
# True
# <class 'bool'>

# %%
# Q2. What will be the output? What does the type() function tell us?
# student_name = "Akshay"
# print(student_name)
# print(type(student_name))

student_name = "Akshay"
print(student_name)
print(type(student_name))
# Out:
# Akshay
# <class 'str'>

# %%
# Q3. What will be the output? What does id() return?
# city = "Pune"
# print(city)
# print(id(city))


city = "Pune"
print(city)
print(id(city))
# Out:
# Pune
# 1784544755456

# %%
# Q4. What will be the output of this single print statement with multiple values?
# player = "Rohit"
# runs = 150
# avg = 45.6
# print(player, runs, avg)

player = "Rohit"
runs = 150
avg = 45.6
print(player, runs, avg)
# Out:
# Rohit 150 45.6

# %%
# Q5. What will be the output? What is the default separator in print()?
# fruit1 = "Mango"
# fruit2 = "Banana"
# fruit3 = "Apple"
# print(fruit1, fruit2, fruit3)


fruit1 = "Mango"
fruit2 = "Banana"
fruit3 = "Apple"
print(fruit1, fruit2, fruit3)
# Out:
# Mango Banana Apple

# %%
# Q6. What will be the output? What does sep="-" do?
# brand = "Nike"
# product = "Shoes"
# price = 3999
# print(brand, product, price, sep="-")


brand = "Nike"
product = "Shoes"
price = 3999
print(brand, product, price, sep="-")
# Out:
# Nike-Shoes-3999

# %%
# Q7. What will be the output? How is sep="," different from the default behavior?
# subject1 = "Python"
# subject2 = "SQL"
# subject3 = "Machine Learning"
# print(subject1, subject2, subject3, sep=", ")


subject1 = "Python"
subject2 = "SQL"
subject3 = "Machine Learning"
print(subject1, subject2, subject3, sep=", ")
# Out:
# Python, SQL, Machine Learning

# %%
# Q8. What will be the output? What does end=" " do in print()?
# roll_no = 101
# dept = "Computer"
# year = 2024
# print(roll_no, end=" ")
# print(dept, end=" ")
# print(year)


roll_no = 101
dept = "Computer"
year = 2024
print(roll_no, end=" ")
print(dept, end=" ")
print(year)
# Out:
# 101 Computer 2024

# %%
# Q9. What will be the output? What does end="\n" do and is it different from default behavior?
# course = "Data Science"
# duration = "6 months"
# fees = 25000
# print(course, end="\n")
# print(duration, end="\n")
# print(fees, end="\n")
# print("Enrollment open")


course = "Data Science"
duration = "6 months"
fees = 25000
print(course, end="\n")
print(duration, end="\n")
print(fees, end="\n")
print("Enrollment open")
# Out:
# Data Science
# 6 months
# 25000
# Enrollment open

# %%
# Q10. What will be the output? Explain what happens when you print a label with a variable.
# employee = "Suresh"
# salary = 45000
# print("Employee Name :", employee)
# print("Salary :", salary)


employee = "Suresh"
salary = 45000
print("Employee Name :", employee)
print("Salary :", salary)
# Out:
# Employee Name : Suresh
# Salary : 45000

# %%
# Q11. What will be the output? What does input() always return regardless of what the user types?
# user_age = input("Enter your age: ")
# print(user_age)
# print(type(user_age))


user_age = input("Enter your age: ")
print(user_age)
print(type(user_age))
# Out:
# <class 'str'>

# %%
# Q12. What will be the output? Why is the type str even though user typed a number?
# pin_code = input("Enter your pin code: ")
# print(pin_code)
# print(type(pin_code))


pin_code = input("Enter your pin code: ")
print(pin_code)
print(type(pin_code))
# Out:
# <class 'str'>

# %%
# Q13. What will be the output? How do you take integer input from user?
# quantity = int(input("Enter quantity: "))
# print(quantity)
# print(type(quantity))

quantity = int(input("Enter quantity: "))
print(quantity)
print(type(quantity))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 6
#       2 # quantity = int(input("Enter quantity: "))
#       3 # print(quantity)
#       4 # print(type(quantity))
#       5
# ----> 6 quantity = int(input("Enter quantity: "))
#       7 print(quantity)
#       8 print(type(quantity))
#
# ValueError: invalid literal for int() with base 10: ''

# %%
# Q14. What will be the output? How do you take float input from user?
# temperature = float(input("Enter temperature: "))
# print(temperature)
# print(type(temperature))


temperature = float(input("Enter temperature: "))
print(temperature)      
print(type(temperature))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 7
#       3 # print(temperature)
#       4 # print(type(temperature))
#       5
#       6
# ----> 7 temperature = float(input("Enter temperature: "))
#       8 print(temperature)
#       9 print(type(temperature))
#
# ValueError: could not convert string to float: ''

# %%
temperature = float(input("Enter temperature: "))
print(temperature)      
print(type(temperature))

# %%
# Q15. What will be the output? Explain what each line does.
# first_name = input("Enter first name: ")
# last_name = input("Enter last name: ")
# print("Full Name :", first_name, last_name)
# print("Hello", first_name, "welcome to Python class!")


first_name = input("Enter first name: ")
last_name = input("Enter last name: ")
print("Full Name :", first_name, last_name)
print("Hello", first_name, "welcome to Python class!")
# Out:
# Full Name :
# Hello  welcome to Python class!
